# %%
path = r'/content/Low_quality_ML_img.jpg'
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter
import numpy as np
from scipy.ndimage.filters import convolve
# Out:
# /tmp/ipython-input-3785340295.py:7: DeprecationWarning: Please import `convolve` from the `scipy.ndimage` namespace; the `scipy.ndimage.filters` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.filters import convolve

# %%
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/Low_quality_ML_img.jpg',cv2.IMREAD_GRAYSCALE)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=225x150>

# %%
#kernal declaration
identity=np.array([[0,0,0],[0,1,0],[0,0,0]])
blur_kernal=np.ones((7,7),dtype=float)*(1/6)
horizontal_kernal=np.array([[1,2,1],[0,0,0],[-1,-2,-1]])
horizontal_kernal
# Out:
# array([[ 1,  2,  1],
#        [ 0,  0,  0],
#        [-1, -2, -1]])

# %%
kernal=horizontal_kernal
img2=convolve(img,kernal)

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=225x150>
